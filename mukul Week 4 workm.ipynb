# %%
# Week 4 Classwork Pandas

# %%
import pandas as pd

# %%
df1 = pd.read_excel(r"ElectricCarData_Clean.xlsx" , sheet_name="COC",header= None)
df1
# Out:
#              0            1      2                      3      4         5   \
# 0   attackerTag  defenderTag  stars  destructionPercentage  order  duration
# 1    #QJUCV989Q   #LVP9V20C0      1                     60      1       123
# 2    #QJUCV989Q   #92PQCC2PG      0                     37      2        69
# 3    #QCQPCU2PC   #LVP9V20C0      2                     65      3       100
# 4    #L2U9QV0LJ   #LQC2YC0UP      1                     64      4       124
# ..          ...          ...    ...                    ...    ...       ...
# 95    #YJVJP8VG   #2RRRVVRJP      1                     66     22       102
# 96   #2RRRVVRJP    #QY2PUC2G      2                     76     23       179
# 97   #22RL0PRPR    #UPU0L2VU      2                     83     24       116
# 98   #8JUPVY0YV   #2RRRVVRJP      1                     55     25       154
# 99   #8JUPVY0YV    #C0G8PGQC      2                     96     26       175
#
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = pd.read_excel(r"ElectricCarData_Clean.xlsx" , sheet_name="EV",header= None)
df2
# Out:
#               0                                1         2             3   \
# 0          Brand                            Model  AccelSec  TopSpeed_KmH
# 1         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 2    Volkswagen                         ID.3 Pure        10           160
# 3      Polestar                                 2       4.7           210
# 4           BMW                              iX3        6.8           180
# ..           ...                              ...       ...           ...
# 99       Nissan                       Ariya 63kWh       7.5           160
# 100        Audi     e-tron S Sportback 55 quattro       4.5           210
# 101      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 102      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 103       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#            4                5               6            7           8   \
# ...

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel(r"ElectricCarData_Clean.xlsx" , sheet_name="EV", header = None, names = ['A','B'])
# Out:
#                                                                                                                                                                    A  \
# Brand       Model                           AccelSec TopSpeed_KmH Range_Km Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain PlugType   BodyStyle Segment  Seats
# Tesla       Model 3 Long Range Dual Motor   4.6      233          450      161             940            Yes         AWD        Type 2 CCS Sedan     D            5
# Volkswagen  ID.3 Pure                       10       160          270      167             250            Yes         RWD        Type 2 CCS Hatchback C            5
# Polestar    2                               4.7      210          400      181             620            Yes         AWD        Type 2 CCS Liftback  D            5
# ...

# %%
df1.head()
# Out:
#             0            1      2                      3      4         5   \
# 0  attackerTag  defenderTag  stars  destructionPercentage  order  duration
# 1   #QJUCV989Q   #LVP9V20C0      1                     60      1       123
# 2   #QJUCV989Q   #92PQCC2PG      0                     37      2        69
# 3   #QCQPCU2PC   #LVP9V20C0      2                     65      3       100
# 4   #L2U9QV0LJ   #LQC2YC0UP      1                     64      4       124
#
#                        6                  7                  8   \
# 0  attacker_townHallLevel  attacker_expLevel  attacker_trophies
# 1                       9                 42                920
# 2                       9                 42                920
# 3                       9                 44                952
# 4                      13                149               2523
#
#                       9                  10                   11  \
# ...

# %%
df2.tail()
# Out:
#           0                                1    2    3    4    5    6    7   \
# 99   Nissan                       Ariya 63kWh  7.5  160  330  191  440  Yes
# 100    Audi     e-tron S Sportback 55 quattro  4.5  210  335  258  540  Yes
# 101  Nissan               Ariya e-4ORCE 63kWh  5.9  200  325  194  440  Yes
# 102  Nissan   Ariya e-4ORCE 87kWh Performance  5.1  200  375  232  450  Yes
# 103   Byton                 M-Byte 95 kWh 2WD  7.5  190  400  238  480  Yes
#
#       8           9          10 11 12     13
# 99   FWD  Type 2 CCS  Hatchback  C  5  45000
# 100  AWD  Type 2 CCS        SUV  E  5  96050
# 101  AWD  Type 2 CCS  Hatchback  C  5  50000
# 102  AWD  Type 2 CCS  Hatchback  C  5  65000
# 103  AWD  Type 2 CCS        SUV  E  5  62000

# %%
k = pd.read_csv("ElectricCarData_Clean.csv")
k
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
pd.read_csv('ElectricCarData_Clean.csv',names=['model','brand'])
# Out:
#                                                                                                                                                                model  \
# Brand       Model                           AccelSec TopSpeed_KmH Range_Km Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain PlugType   BodyStyle Segment  Seats
# Tesla       Model 3 Long Range Dual Motor   4.6      233          450      161             940            Yes         AWD        Type 2 CCS Sedan     D            5
# Volkswagen  ID.3 Pure                       10       160          270      167             250            Yes         RWD        Type 2 CCS Hatchback C            5
# Polestar    2                               4.7      210          400      181             620            Yes         AWD        Type 2 CCS Liftback  D            5
# ...

# %%
pd.read_csv("ElectricCarData_Clean.csv",sep='@')
# Out:
#     Brand,Model,AccelSec,TopSpeed_KmH,Range_Km,Efficiency_WhKm,FastCharge_KmH,RapidCharge,PowerTrain,PlugType,BodyStyle,Segment,Seats,PriceEuro
# 0    Tesla ,Model 3 Long Range Dual Motor,4.6,233,4...
# 1    Volkswagen ,ID.3 Pure,10,160,270,167,250,Yes,R...
# 2    Polestar ,2,4.7,210,400,181,620,Yes,AWD,Type 2...
# 3    BMW ,iX3 ,6.8,180,360,206,560,Yes,RWD,Type 2 C...
# 4    Honda ,e ,9.5,145,170,168,190,Yes,RWD,Type 2 C...
# ..                                                 ...
# 98   Nissan ,Ariya 63kWh,7.5,160,330,191,440,Yes,FW...
# 99   Audi ,e-tron S Sportback 55 quattro,4.5,210,33...
# 100  Nissan ,Ariya e-4ORCE 63kWh,5.9,200,325,194,44...
# 101  Nissan ,Ariya e-4ORCE 87kWh Performance,5.1,20...
# 102  Byton ,M-Byte 95 kWh 2WD,7.5,190,400,238,480,Y...
#
# [103 rows x 1 columns]

# %%
k.tail()
# Out:
#        Brand                            Model  AccelSec  TopSpeed_KmH  \
# 98   Nissan                       Ariya 63kWh       7.5           160
# 99     Audi     e-tron S Sportback 55 quattro       4.5           210
# 100  Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101  Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102   Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 98        330              191            440         Yes        FWD
# 99        335              258            540         Yes        AWD
# 100       325              194            440         Yes        AWD
# 101       375              232            450         Yes        AWD
# 102       400              238            480         Yes        AWD
#
#        PlugType  BodyStyle Segment  Seats  PriceEuro
# 98   Type 2 CCS  Hatchback       C      5      45000
# ...

# %%
type(k)
# Out:
# pandas.core.frame.DataFrame

# %%
len(k)
# Out:
# 103

# %%
k.columns
# Out:
# Index(['Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge', 'PowerTrain',
#        'PlugType', 'BodyStyle', 'Segment', 'Seats', 'PriceEuro'],
#       dtype='object')

# %%
k.dtypes
# Out:
# Brand               object
# Model               object
# AccelSec           float64
# TopSpeed_KmH         int64
# Range_Km             int64
# Efficiency_WhKm      int64
# FastCharge_KmH      object
# RapidCharge         object
# PowerTrain          object
# PlugType            object
# BodyStyle           object
# Segment             object
# Seats                int64
# PriceEuro            int64
# dtype: object

# %%
k[['Brand','Model','PriceEuro']]
# Out:
#            Brand                            Model  PriceEuro
# 0         Tesla     Model 3 Long Range Dual Motor      55480
# 1    Volkswagen                         ID.3 Pure      30000
# 2      Polestar                                 2      56440
# 3           BMW                              iX3       68040
# 4         Honda                                e       32997
# ..           ...                              ...        ...
# 98       Nissan                       Ariya 63kWh      45000
# 99         Audi     e-tron S Sportback 55 quattro      96050
# 100      Nissan               Ariya e-4ORCE 63kWh      50000
# 101      Nissan   Ariya e-4ORCE 87kWh Performance      65000
# 102       Byton                 M-Byte 95 kWh 2WD      62000
#
# [103 rows x 3 columns]

# %%
k.describe()
# Out:
#          AccelSec  TopSpeed_KmH    Range_Km  Efficiency_WhKm       Seats  \
# count  103.000000    103.000000  103.000000       103.000000  103.000000
# mean     7.396117    179.194175  338.786408       189.165049    4.883495
# std      3.017430     43.573030  126.014444        29.566839    0.795834
# min      2.100000    123.000000   95.000000       104.000000    2.000000
# 25%      5.100000    150.000000  250.000000       168.000000    5.000000
# 50%      7.300000    160.000000  340.000000       180.000000    5.000000
# 75%      9.000000    200.000000  400.000000       203.000000    5.000000
# max     22.400000    410.000000  970.000000       273.000000    7.000000
#
#            PriceEuro
# count     103.000000
# mean    55811.563107
# std     34134.665280
# min     20129.000000
# 25%     34429.500000
# 50%     45000.000000
# 75%     65000.000000
# max    215000.000000

# %%
k.dtypes == 'object'
# Out:
# Brand               True
# Model               True
# AccelSec           False
# TopSpeed_KmH       False
# Range_Km           False
# Efficiency_WhKm    False
# FastCharge_KmH      True
# RapidCharge         True
# PowerTrain          True
# PlugType            True
# BodyStyle           True
# Segment             True
# Seats              False
# PriceEuro          False
# dtype: bool

# %%
k.dtypes[k.dtypes == 'object']
# Out:
# Brand             object
# Model             object
# FastCharge_KmH    object
# RapidCharge       object
# PowerTrain        object
# PlugType          object
# BodyStyle         object
# Segment           object
# dtype: object

# %%
k.dtypes[k.dtypes == 'object'].index
# Out:
# Index(['Brand', 'Model', 'FastCharge_KmH', 'RapidCharge', 'PowerTrain',
#        'PlugType', 'BodyStyle', 'Segment'],
#       dtype='object')

# %%
k[k.dtypes[k.dtypes == 'object'].index]
# Out:
#            Brand                            Model FastCharge_KmH RapidCharge  \
# 0         Tesla     Model 3 Long Range Dual Motor            940         Yes
# 1    Volkswagen                         ID.3 Pure            250         Yes
# 2      Polestar                                 2            620         Yes
# 3           BMW                              iX3             560         Yes
# 4         Honda                                e             190         Yes
# ..           ...                              ...            ...         ...
# 98       Nissan                       Ariya 63kWh            440         Yes
# 99         Audi     e-tron S Sportback 55 quattro            540         Yes
# 100      Nissan               Ariya e-4ORCE 63kWh            440         Yes
# 101      Nissan   Ariya e-4ORCE 87kWh Performance            450         Yes
# 102       Byton                 M-Byte 95 kWh 2WD            480         Yes
#
# ...

# %%
k[k.dtypes[k.dtypes == 'object'].index].describe()
# Out:
#          Brand          Model FastCharge_KmH RapidCharge PowerTrain  \
# count      103            103            103         103        103
# unique      33            102             51           2          3
# top     Tesla   e-Soul 64 kWh            230         Yes        AWD
# freq        13              2              6          98         41
#
#           PlugType BodyStyle Segment
# count          103       103     103
# unique           4         9       8
# top     Type 2 CCS       SUV       C
# freq            90        45      30

# %%
k.dtypes[k.dtypes == 'float']
# Out:
# AccelSec    float64
# dtype: object

# %%
k[k.dtypes[k.dtypes == 'float'].index]
# Out:
#      AccelSec
# 0         4.6
# 1        10.0
# 2         4.7
# 3         6.8
# 4         9.5
# ..        ...
# 98        7.5
# 99        4.5
# 100       5.9
# 101       5.1
# 102       7.5
#
# [103 rows x 1 columns]

# %%
k[k.dtypes[k.dtypes == 'float'].index].describe
# Out:
# <bound method NDFrame.describe of      AccelSec
# 0         4.6
# 1        10.0
# 2         4.7
# 3         6.8
# 4         9.5
# ..        ...
# 98        7.5
# 99        4.5
# 100       5.9
# 101       5.1
# 102       7.5
#
# [103 rows x 1 columns]>

# %%
k['Brand']
# Out:
# 0           Tesla
# 1      Volkswagen
# 2        Polestar
# 3             BMW
# 4           Honda
#           ...
# 98         Nissan
# 99           Audi
# 100        Nissan
# 101        Nissan
# 102         Byton
# Name: Brand, Length: 103, dtype: object

# %%
 k['Brand'][1:14:2]
# Out:
# 1     Volkswagen
# 3            BMW
# 5          Lucid
# 7        Peugeot
# 9           Audi
# 11        Nissan
# 13           BMW
# Name: Brand, dtype: object

# %%
k
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
k.columns
# Out:
# Index(['Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge', 'PowerTrain',
#        'PlugType', 'BodyStyle', 'Segment', 'Seats', 'PriceEuro'],
#       dtype='object')

# %%
k['TopSpeed_KmH']== max(k['TopSpeed_KmH'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 98     False
# 99     False
# 100    False
# 101    False
# 102    False
# Name: TopSpeed_KmH, Length: 103, dtype: bool

# %%
k['TopSpeed_KmH']
# Out:
# 0      233
# 1      160
# 2      210
# 3      180
# 4      145
#       ...
# 98     160
# 99     210
# 100    200
# 101    200
# 102    190
# Name: TopSpeed_KmH, Length: 103, dtype: int64

# %%
k[k['PowerTrain']== 'RWD']
# Out:
#           Brand                        Model  AccelSec  TopSpeed_KmH  \
# 1   Volkswagen                     ID.3 Pure      10.0           160
# 3          BMW                          iX3        6.8           180
# 4        Honda                            e        9.5           145
# 8        Tesla   Model 3 Standard Range Plus       5.6           225
# 13         BMW                           i4        4.0           200
# 15  Volkswagen                    ID.3 Pro S       7.9           160
# 22       Skoda                   Enyaq iV 50      10.0           160
# 25  Volkswagen                         ID.4        7.5           160
# 26  Volkswagen                      ID.3 Pro       9.0           160
# 28         BMW                     i3 120 Ah       7.3           150
# 37       CUPRA                      el-Born        6.5           160
# 53       Skoda                   Enyaq iV 80       8.8           160
# 55       Honda                     e Advance       8.3           145
# ...

# %%
len(k[k['PowerTrain']== 'RWD'])
# Out:
# 25

# %%
k[k['AccelSec']>10.0]
# Out:
#           Brand              Model  AccelSec  TopSpeed_KmH  Range_Km  \
# 17  Volkswagen              e-Up!       11.9           130       195
# 32     Renault       Zoe ZE50 R110      11.4           135       315
# 43       Skoda         CITIGOe iV       12.3           130       195
# 44        SEAT       Mii Electric       12.3           130       195
# 57     Renault           Twingo ZE      12.6           135       130
# 60     Renault       Zoe ZE40 R110      11.4           135       255
# 66      Nissan     e-NV200 Evalia       14.0           123       190
# 68     Renault   Kangoo Maxi ZE 33      22.4           130       160
# 77       Smart         EQ forfour       12.7           130        95
# 82       Smart     EQ fortwo coupe      11.6           130       100
# 91       Smart    EQ fortwo cabrio      11.9           130        95
#
#     Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain        PlugType  \
# ...

# %%
k[k['AccelSec']>10.0]['Brand']
# Out:
# 17    Volkswagen
# 32       Renault
# 43         Skoda
# 44          SEAT
# 57       Renault
# 60       Renault
# 66        Nissan
# 68       Renault
# 77         Smart
# 82         Smart
# 91         Smart
# Name: Brand, dtype: object

# %%
(k['AccelSec']>10.0) & (k['Brand']== 'Smart')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 98     False
# 99     False
# 100    False
# 101    False
# 102    False
# Length: 103, dtype: bool

# %%
data = {'name' : ['Kaushik', 'Avadhut','Soham','Alita'], 
       'salary': [1234, 3200, 1300, 123400],
       'email': ['kt@mes.ac.in', 'ap@mes.ac.in', 'sb@mes.ac.in','a@mes.ac.in'],
       'addr': ['PNVL', 'MNSR', 'SHRVDN', 'DIGI']}
ab = pd.DataFrame(data)
ab
# Out:
#       name  salary         email    addr
# 0  Kaushik    1234  kt@mes.ac.in    PNVL
# 1  Avadhut    3200  ap@mes.ac.in    MNSR
# 2    Soham    1300  sb@mes.ac.in  SHRVDN
# 3    Alita  123400   a@mes.ac.in    DIGI

# %%
pd.DataFrame(data,index = [4,5,6,7])
# Out:
#       name  salary         email    addr
# 4  Kaushik    1234  kt@mes.ac.in    PNVL
# 5  Avadhut    3200  ap@mes.ac.in    MNSR
# 6    Soham    1300  sb@mes.ac.in  SHRVDN
# 7    Alita  123400   a@mes.ac.in    DIGI

# %%
ab.loc[4:7]
# Out:
# Empty DataFrame
# Columns: [name, salary, email, addr]
# Index: []

# %%
ab.iloc[1:3]
# Out:
#       name  salary         email    addr
# 1  Avadhut    3200  ap@mes.ac.in    MNSR
# 2    Soham    1300  sb@mes.ac.in  SHRVDN
